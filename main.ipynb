# %% [markdown]
# # Functions

# %% [markdown]
# En este laboratorio pondremos en práctica algunos de los conceptos que hemos aprendido en los últimos días.
#
# `NOTA: En este laboratorio deberías intentar escribir todas las funciones por ti mismo utilizando solo la sintaxis más básica de Python y sin funciones como len, count, sum, max, min, in, etc. Dale una oportunidad. 🧑🏻‍💻👩🏻‍💻`
#
# La celda después de cada ejercicio contiene algunas pruebas para verificar si tu función funciona como se espera.

# %%
from mod.testing import *
import unittest

# %% [markdown]
# ## 1. Escribe una función que devuelva el mayor de dos números

# %%
def greater(a,b):
    if a > b:
        return a
    else:
        return b

# %%
# Para testear tu función
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.034s
#
# OK

# %% [markdown]
# ## 2. Ahora escribe una función que devuelva el elemento más

# %%
def greatest(lista):
    max_value = lista[0]
    for i in lista:
        if i > max_value:
            max_value = i
    return max_value

# %%
# Para testear tu función
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.022s
#
# OK

# %% [markdown]
# ## 3. Escribe una función que sume todos los elementos de una lista

# %%
def sum_all(lst):
    suma = 0
    for i in lst:
        suma += i
    return suma

# %%
# Para testear tu función
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.022s
#
# OK

# %% [markdown]
# ## 4. Escribe otra función que multiplique todos los elementos de una lista

# %%
def mult_all(lst):
    mult = 1
    for i in lst:
        mult *= i
    return mult

# %%
# Para testear tu función
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.025s
#
# OK

# %% [markdown]
# ## 5. Ahora combina esas dos ideas y escribe una función que reciba una lista y ya sea "+" o "*", y produzca el resultado acorde

# %%
def oper_all(arr, oper = "*"):
    if oper == "*":
        value = 1
        for i in arr:
            value *= i
    else:
        value = 0
        for i in arr:
            value += i
    return value

# %%
# Para testear tu función
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.027s
#
# OK

# %% [markdown]
# ## 6. Escribe una función que devuelva el factorial de un número.

# %%
def factorial(n):
    result = n
    n -= 1
    while n > 0:
        result *= n
        n -= 1
    return result

# %%
# Fórmula factorial
# n! = n * (n - 1) *...*1

# Este código define una función llamada "factorial" que toma una entrada "n". La función utiliza un bucle for para iterar a través del rango de números
# desde 1 hasta n+1. Para cada número en ese rango, multiplica el valor actual de x por el número en el rango. Al final del bucle,
# la función devuelve el valor final de x, que será el factorial del número de entrada "n".

# El factorial de un entero positivo n es el producto de todos los enteros positivos menores o iguales a n.
# Por ejemplo, el factorial de 6 (escrito "6!") es 6 * 5 * 4 * 3 * 2 * 1 = 720.

# Así que esta función toma una entrada de cualquier entero positivo y devuelve el factorial de ese número.

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.026s
#
# OK

# %% [markdown]
# ## 7. Escribe una función que tome una lista y devuelva una lista de los valores únicos.
#
# `NOTE: No podemos usar set. 🤔`

# %%
def unique(lst_un):
    lista = list()
    for i in lst_un:
        found = False
        for j in lista:
            if i == j:
                found = True
        if not found:
            lista.append(i)
    return lista

# %%
# Para testear tu función 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.147s
#
# OK

# %% [markdown]
# ## 8. Escribe una función que devuelva la moda de una lista, es decir: el elemento que aparece más veces.
#
# `NOTE: No se debe usar count... 🧐`

# %%
def mode_counter(arr):
    most_common_value = None
    most_common_count = 0
    dict_counter = {}
    for i in arr:
        if i in dict_counter:
            dict_counter[i] += 1
        else:
            dict_counter[i] = 1
        if dict_counter[i] > most_common_count:
            most_common_value = i
            most_common_count = dict_counter[i]
    return most_common_value

# %%
# Para testear tu función 
test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.024s
#
# OK

# %% [markdown]
# ## 9. Escribe una función que calcule la desviación estándar de una lista.
# `NOTE: no utilices librerías ni ninguna función ya construida. 😉`

# %%
from math import sqrt

def st_dev(list_sd):
    sumatorio = 0
    counter = 0
    for i in list_sd:
        sumatorio += i
        counter += 1
    media = sumatorio / counter
    sumatorio = 0
    for i in list_sd:
        
    return (sumatorio / counter)**0.5

# %%
# Para testear tu función
test_stdev(st_dev)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 5.211733124610484 != 592.3576073513717 within 5 delta (587.1458742267612 difference) : Should be 592.3576073513717
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 8.917126864363404 != 594.5251302814125 within 5 delta (585.6080034170492 difference) : Should be 594.5251302814125
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 5.452678911972827 != 597.6614105815128 within 5 delta (592.2087316695399 difference) : Should be 597.6614105815128
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: (2.9013113916208357e-16+4.7382010774712215j) != 521.0704209975688 within 5 delta (521.0919632733114 difference) : Should be 521.0704209975688
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 5.800444921755794 != 531.725015667041 within 5 delta (525.9245707452852 difference) : Should be 531.725015667041
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 7.501412296406455 != 579.2146832806282 within 5 delta (571.7132709842217 difference) : Should be 579.2146832806282
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 4.979369201722124 != 575.1096221939839 within 5 delta (570.1302529922618 difference) : Should be 575.1096221939839
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 6.2281195945654835 != 602.9365711017452 within 5 delta (596.7084515071798 difference) : Should be 602.9365711017452
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 11.36962148371382 != 565.1723444952294 within 5 delta (553.8027230115156 difference) : Should be 565.1723444952294
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 7.749193506423749 != 538.2187327075193 within 5 delta (530.4695392010956 difference) : Should be 538.2187327075193
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 1.6943930305379222 != 651.5820614440662 within 5 delta (649.8876684135283 difference) : Should be 651.5820614440662
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 8.496935722168708 != 626.0119827303067 within 5 delta (617.515047008138 difference) : Should be 626.0119827303067
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 4.827993766516669 != 569.2606910423691 within 5 delta (564.4326972758524 difference) : Should be 569.2606910423691
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 7.358668357794092 != 611.0799133716603 within 5 delta (603.7212450138662 difference) : Should be 611.0799133716603
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: (2.8176858145411115e-16+4.601630145937415j) != 513.9732053027967 within 5 delta (513.9938042128823 difference) : Should be 513.9732053027967
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 5.681729603039138 != 526.9048625160427 within 5 delta (521.2231329130036 difference) : Should be 526.9048625160427
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: (2.7615461263689943e-16+4.509947077462155j) != 526.5912494305027 within 5 delta (526.6105616102087 difference) : Should be 526.5912494305027
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: (6.212117985212817e-16+10.145158570680028j) != 532.2796058350149 within 5 delta (532.3762795526328 difference) : Should be 532.2796058350149
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 4.006843460948773 != 600.670109368856 within 5 delta (596.6632659079072 difference) : Should be 600.670109368856
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: (5.870122333587186e-16+9.586637286235009j) != 514.6181064387273 within 5 delta (514.7073917178955 difference) : Should be 514.6181064387273
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 11.480753124586048 != 544.5199019103192 within 5 delta (533.0391487857331 difference) : Should be 544.5199019103192
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: (2.4750311905046707e-16+4.042032677875587j) != 610.5232169134455 within 5 delta (610.5365971164308 difference) : Should be 610.5232169134455
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 5.4182232195751086 != 609.7511023625117 within 5 delta (604.3328791429366 difference) : Should be 609.7511023625117
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: (1.0029638276579423e-16+1.6379642332078845j) != 508.40741119135043 within 5 delta (508.4100497444166 difference) : Should be 508.40741119135043
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError:
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 4.106748667179989 != 612.4521599194873 within 5 delta (608.3454112523073 difference) : Should be 612.4521599194873
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 9.079623364411127 != 567.4856279881791 within 5 delta (558.406004623768 difference) : Should be 567.4856279881791
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 8.142688179373987 != 569.8585232018395 within 5 delta (561.7158350224655 difference) : Should be 569.8585232018395
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 10.024414640710393 != 514.4059955743404 within 5 delta (504.38158093363 difference) : Should be 514.4059955743404
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: (4.902145923681814e-16+8.005811842393872j) != 622.2714464326675 within 5 delta (622.3229435499386 difference) : Should be 622.2714464326675
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 14.903611879635873 != 512.1864751183085 within 5 delta (497.28286323867263 difference) : Should be 512.1864751183085
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 1.713913650100261 != 547.2738396681376 within 5 delta (545.5599260180373 difference) : Should be 547.2738396681376
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 5.577858011817798 != 586.1308877403503 within 5 delta (580.5530297285325 difference) : Should be 586.1308877403503
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 11.19059909909748 != 561.5603082318237 within 5 delta (550.3697091327263 difference) : Should be 561.5603082318237
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: (4.651963516218689e-16+7.597232964569977j) != 520.5901989047445 within 5 delta (520.6456310624333 difference) : Should be 520.5901989047445
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: (5.599495776967285e-16+9.144670579085941j) != 613.8723598546757 within 5 delta (613.9404687700171 difference) : Should be 613.8723598546757
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 11.385454379539336 != 605.1897167643473 within 5 delta (593.804262384808 difference) : Should be 605.1897167643473
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: (1.7967833116414333e-16+2.9343698328243275j) != 554.7162643465316 within 5 delta (554.7240254909525 difference) : Should be 554.7162643465316
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 11.929718429962286 != 609.6867569157473 within 5 delta (597.7570384857851 difference) : Should be 609.6867569157473
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 5.244044240850758 != 576.6367531253493 within 5 delta (571.3927088844986 difference) : Should be 576.6367531253493
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: (1.9980009151126834e-16+3.2629831172608617j) != 616.3116035310862 within 5 delta (616.3202411943668 difference) : Should be 616.3116035310862
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 12.30853362509117 != 620.4557708945607 within 5 delta (608.1472372694695 difference) : Should be 620.4557708945607
#
# ======================================================================
# FAIL: runTest (mod.testing.test_stdev.<locals>.TestKnown)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/mcabre/Escriptori/ironhack/lab-functions-es/mod/testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 10.960725340961702 != 506.95888390317657 within 5 delta (495.9981585622149 difference) : Should be 506.95888390317657
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.032s
#
# FAILED (failures=100)

# %% [markdown]
# ## 10. Escribe una función para verificar si una cadena es un pangrama, es decir: si contiene todas las letras del alfabeto al menos una vez. Ten en cuenta que las cadenas pueden contener caracteres que no son letras.

# %%
def pangram(string):
#tu codigo aquí

# %%
# Para testear tu función
test_pangram(pangram)

# %% [markdown]
# ## 11. Escribe una función que reciba una cadena de palabras separadas por comas y devuelva una cadena de palabras separadas por comas ordenadas alfabéticamente.
#
# `NOTA: Puedes usar sorted pero no split y definitivamente no join! 🤪`

# %%
def sort_alpha(string):
#tu codigo aquí

# %%
# Para testear tu función 
test_alpha(sort_alpha)

# %% [markdown]
# ## 12. Escribe una función para verificar si una contraseña dada es fuerte (al menos 8 caracteres, al menos una minúscula, al menos una mayúscula, al menos un número y al menos un carácter especial). Debería devolver True si es fuerte y False si no lo es.

# %%
def check_pass(password):
#tu codigo aquí

# %%
# Para testear tu función
test_pass(check_pass)
